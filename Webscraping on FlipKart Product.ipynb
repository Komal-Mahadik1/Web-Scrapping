# %%
from bs4 import BeautifulSoup as bs

# %%
import requests

# %%
url="https://www.flipkart.com/red-chief-boots-men/p/itmf3yypjzggzhy4?pid=SHOF9FF37ASRDE7B&lid=LSTSHOF9FF37ASRDE7BT73ZPO&marketplace=FLIPKART&store=osp%2Fcil&srno=b_1_1&otracker=hp_omu_Pick%2BYour%2BStyles_2_33.dealCard.OMU_DBO6DFC8KDX6_16&otracker1=hp_omu_PINNED_neo%2Fmerchandising_Pick%2BYour%2BStyles_NA_dealCard_cc_2_NA_view-all_16&fm=neo%2Fmerchandising&iid=en_qP1gOl06uZSDBI07Fq3SJ%2BEFcR3Rq05H2Twu9fV2ofiMEf4zZXY6Ck3Cz2VD3%2BQUmgUYhLTVU8g%2Fdbmf8A6bbg%3D%3D&ppt=browse&ppn=browse&ssid=y4vbe0z01s0000001669384445825"

# %%
content_=requests.get(url)

# %%
print(content_)
# Out:
# <Response [200]>

# %%
content_.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57
# ...

# %%
soup=bs(content_.content,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# print(soup.prettify())

# %% [markdown]
# ### Title of the product

# %%
title=soup.title

# %%
print(title)
# Out:
# <title>RED CHIEF Boots For Men - Buy RED CHIEF Boots For Men Online at Best Price - Shop Online for Footwears in India | Flipkart.com</title>

# %%
print(title.string)
# Out:
# RED CHIEF Boots For Men - Buy RED CHIEF Boots For Men Online at Best Price - Shop Online for Footwears in India | Flipkart.com

# %%
price=soup.find_all("div",class_="_30jeq3 _16Jk6d")

# %%
price
# Out:
# [<div class="_30jeq3 _16Jk6d">₹2,759</div>]

# %%
product_price=[]
for i in range(0,len(price)):
    product_price.append(price[i].get_text())
product_price
# Out:
# ['₹2,759']

# %% [markdown]
# ## Get all the customer name

# %%
name=soup.find_all("p",class_="_2sc7ZR _2V5EHH _1QgsS5")

# %%
name
# Out:
# [<p class="_2sc7ZR _2V5EHH _1QgsS5">Baljinder singh BALJINDER singh </p>,
#  <p class="_2sc7ZR _2V5EHH _1QgsS5">Flipkart Customer</p>,
#  <p class="_2sc7ZR _2V5EHH _1QgsS5">Flipkart Customer</p>]

# %%
cust_name=[]
for i in range(0,len(name)):
    cust_name.append(name[i].get_text())
cust_name
# Out:
# ['Baljinder singh BALJINDER singh ', 'Flipkart Customer', 'Flipkart Customer']

# %% [markdown]
# ## review

# %%
rew=soup.find_all("div",class_="_6K-7Co")

# %%
rew
# Out:
# [<div class="_6K-7Co">nice</div>,
#  <div class="_6K-7Co">Best product</div>,
#  <div class="_6K-7Co">Wonderful product</div>]

# %%
cust_rew=[]
for i in range(0,len(rew)):
    cust_rew.append(rew[i].get_text())
cust_rew
# Out:
# ['nice', 'Best product', 'Wonderful product']

# %%
star=soup.find_all("div",class_="_3LWZlK _1BLPMq _3B8WaH")

# %%
star
# Out:
# [<div class="_3LWZlK _1BLPMq _3B8WaH">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq _3B8WaH">4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq _3B8WaH">5<img class="_1wB99o" src="..."/></div>]

# %%
cust_star=[]
for i in range(0,len(star)):
    cust_star.append(star[i].get_text())
cust_star
# Out:
# ['5', '4', '5']

# %%
import pandas as pd

# %%
df=pd.DataFrame()
df["name"]=cust_name
df["review"]=cust_rew
df["stars"]=cust_star
df
# Out:
#                                name             review stars
# 0  Baljinder singh BALJINDER singh                nice     5
# 1                 Flipkart Customer       Best product     4
# 2                 Flipkart Customer  Wonderful product     5
